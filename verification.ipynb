# %%
import pandas as pd
from matplotlib import pyplot as plt
from random import randint

# %%
my_data = pd.read_csv('/Users/kotomi/Unv/Lecture/ds-programming Q4/final/ds-programming_final/data/my_data.csv')
my_data
# Out:
#      5  24
# 0    6  22
# 1    8  23
# 2   10  20
# 3   11  18
# 4   13  20
# 5   13  19
# 6   13  19
# 7   13  20
# 8   14  17
# 9   14  19
# 10  14  19
# 11  15  21
# 12  15  20

# %%
scraping_data = pd.read_csv('/Users/kotomi/Unv/Lecture/ds-programming Q4/final/ds-programming_final/data/scraping_data.csv')
scraping_data
# Out:
#      1  1013.2  1018.4   --  0.0 --.1  10.0  13.1  5.8  45  ...  5.3  10.6  \
# 0    2  1015.0  1020.3  0.5  0.5  0.5   6.6   8.5  4.4  67  ...  2.8   5.3
# 1    3  1008.2  1013.4  0.0  0.0  0.0   8.2  11.5  4.2  73  ...  1.9   3.9
# 2    4  1007.4  1012.6  0.0  0.0  0.0  10.3  15.1  7.1  56  ...  5.0  10.4
# 3    5  1013.7  1018.9   --   --   --   9.1  15.1  4.3  52  ...  2.8   5.8
# 4    6  1007.0  1012.2   --   --   --  10.9  17.5  4.9  59  ...  2.9   7.6
# 5    7  1002.8  1008.0  0.0  0.0  0.0   8.6  11.1  6.2  54  ...  3.1   9.2
# 6    8  1012.3  1017.6   --   --   --   6.2  10.3  3.6  39  ...  3.7   6.8
# 7    9  1011.9  1017.2   --   --   --   6.7  12.6  1.9  46  ...  3.1   6.1
# 8   10  1007.1  1012.3   --   --   --   8.0  12.3  3.4  52  ...  2.8   8.0
# 9   11  1007.9  1013.2   --   --   --   5.7   7.5  4.1  49  ...  5.0   8.6
# 10  12  1003.7  1008.9   --   --   --   8.3  15.2  1.7  51  ...  3.0   7.5
# 11  13  1006.0  1011.2  0.5  0.5  0.5   6.4  12.1  2.0  60  ...  4.1  12.8
# 12  14  1014.4  1019.7   --   --   --   7.4  11.5  1.1  46  ...  5.3  10.0
#
#       北  17.9  北.1  9.4  --.2 --.3            晴        晴後時々曇
# 0   北北西   8.1    北  1.5    --   --       曇時々晴後雨         晴時々曇
# 1     北   5.5    北  1.9    --   --            曇         雨時々曇
# 2     北  18.5    北  6.6    --   --         晴時々曇            晴
# 3   西南西  10.3  西南西  8.6    --   --            晴            晴
# 4   西南西  11.5  西南西  9.2    --   --            晴            晴
# 5     北  15.3    北  3.9    --   --       晴後曇一時雨            晴
# 6   北北西  12.5   北西  9.6    --   --            晴        晴後時々曇
# 7    南西  10.4  南南西  9.5    --   --            晴            晴
# 8     北  12.5    北  5.3    --   --         曇時々晴            曇
# 9     北  13.4    北  0.3    --   --            曇         晴一時曇
# 10  南南西  11.2  南南西  9.6    --   --            晴            晴
# 11    北  19.3    北  6.1    --   --  晴時々曇後雨、雷を伴う  晴一時曇、みぞれを伴う
# 12   南西  18.4   南西  9.6    --   --            晴            晴
#
# [13 rows x 21 columns]
