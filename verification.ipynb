# %%
import pandas as pd
from matplotlib import pyplot as plt
from random import randint

# %%
my_data = pd.read_csv('/Users/kotomi/Unv/Lecture/ds-programming Q4/final/ds-programming_final/data/my_data.csv')
my_data
# Out:
#     日付  気温
# 0    5  24
# 1    6  22
# 2    8  23
# 3   10  20
# 4   11  18
# 5   13  20
# 6   13  19
# 7   13  19
# 8   13  20
# 9   14  17
# 10  14  19
# 11  14  19
# 12  15  21
# 13  15  20

# %%
# 平均気温、最高気温、最低気温を追加
my_data['Average'] = my_data['気温']
my_data['Max'] = my_data['気温']
my_data['min'] = my_data['気温']

# %%
my_data
# Out:
#     日付  気温  Average  Max  min
# 0    5  24       24   24   24
# 1    6  22       22   22   22
# 2    8  23       23   23   23
# 3   10  20       20   20   20
# 4   11  18       18   18   18
# 5   13  20       20   20   20
# 6   13  19       19   19   19
# 7   13  19       19   19   19
# 8   13  20       20   20   20
# 9   14  17       17   17   17
# 10  14  19       19   19   19
# 11  14  19       19   19   19
# 12  15  21       21   21   21
# 13  15  20       20   20   20

# %%
# 複数値があるものの平均気温を出す
# 13日
a = 0
for i in range(len(my_data.iloc[5:9, 1])):
    a += my_data.iloc[5 + i, 1]

average_13 = round(a/len(my_data.iloc[5:9, 1]), 1)
print(average_13)


# 14日
b = 0
for i in range(len(my_data.iloc[9:12, 1])):
    b += my_data.iloc[9 + i, 1]

average_14 = round(b/len(my_data.iloc[9:12, 1]), 1)
print(average_14)

# 15日
c = 0
for i in range(len(my_data.iloc[12:14, 1])):
    c += my_data.iloc[12 + i, 1]

average_15 = round(c/len(my_data.iloc[12:14, 1]), 1)
print(average_15)
# Out:
# 19.5
# 18.3
# 20.5

# %%
# 平均気温、最高気温、最低気温を追加
# 13日
my_data.iloc[5:9, 2] = average_13
my_data.iloc[5:9, 3] = round(max(my_data.iloc[5:9, 1]), 1)
my_data.iloc[5:9, 4] = round(min(my_data.iloc[5:9, 1]), 1)

# 14日
my_data.iloc[9:12, 2] = average_14
my_data.iloc[9:12, 3] = round(max(my_data.iloc[9:12, 1]), 1)
my_data.iloc[9:12, 4] = round(min(my_data.iloc[9:12, 1]), 1)

# 15日
my_data.iloc[12:14, 2] = average_15
my_data.iloc[12:14, 3] = round(max(my_data.iloc[12:14, 1]), 1)
my_data.iloc[12:14, 4] = round(min(my_data.iloc[12:14, 1]), 1)

# %%
n_my_data = my_data.drop('気温', axis=1)

# %%
new_my_data = n_my_data.drop([6, 7, 8, 10, 11, 13, 12])

# %%
new_my_data = new_my_data.rename(columns={'日付': 'date'})

# %%
new_my_data
# Out:
#    date  Average  Max  min
# 0     5     24.0   24   24
# 1     6     22.0   22   22
# 2     8     23.0   23   23
# 3    10     20.0   20   20
# 4    11     18.0   18   18
# 5    13     19.5   20   19
# 9    14     18.3   19   17

# %%
scraping_data = pd.read_csv('/Users/kotomi/Unv/Lecture/ds-programming Q4/final/ds-programming_final/data/scraping_data.csv')
scraping_data
# Out:
#     日付  現地平均気圧  海面平均気圧 合計降水量 最大降水量 最小降水量  平均気温  最高気温  最低気温  平均湿度  ...  平均風速  \
# 0    1  1013.2  1018.4    --   0.0    --  10.0  13.1   5.8    45  ...   5.3
# 1    2  1015.0  1020.3   0.5   0.5   0.5   6.6   8.5   4.4    67  ...   2.8
# 2    3  1008.2  1013.4   0.0   0.0   0.0   8.2  11.5   4.2    73  ...   1.9
# 3    4  1007.4  1012.6   0.0   0.0   0.0  10.3  15.1   7.1    56  ...   5.0
# 4    5  1013.7  1018.9    --    --    --   9.1  15.1   4.3    52  ...   2.8
# 5    6  1007.0  1012.2    --    --    --  10.9  17.5   4.9    59  ...   2.9
# 6    7  1002.8  1008.0   0.0   0.0   0.0   8.6  11.1   6.2    54  ...   3.1
# 7    8  1012.3  1017.6    --    --    --   6.2  10.3   3.6    39  ...   3.7
# 8    9  1011.9  1017.2    --    --    --   6.7  12.6   1.9    46  ...   3.1
# 9   10  1007.1  1012.3    --    --    --   8.0  12.3   3.4    52  ...   2.8
# 10  11  1007.9  1013.2    --    --    --   5.7   7.5   4.1    49  ...   5.0
# 11  12  1003.7  1008.9    --    --    --   8.3  15.2   1.7    51  ...   3.0
# 12  13  1006.0  1011.2   0.5   0.5   0.5   6.4  12.1   2.0    60  ...   4.1
# 13  14  1014.4  1019.7    --    --    --   7.4  11.5   1.1    46  ...   5.3
#
#     最大風速  最大風速(風向) 最大瞬間風速  最大瞬間風速(風向) 日照時間(h)  降雪量(cm) 最新積雪値(cm)        天気概要昼  \
# 0   10.6         北   17.9           北     9.4       --        --            晴
# 1    5.3       北北西    8.1           北     1.5       --        --       曇時々晴後雨
# 2    3.9         北    5.5           北     1.9       --        --            曇
# 3   10.4         北   18.5           北     6.6       --        --         晴時々曇
# 4    5.8       西南西   10.3         西南西     8.6       --        --            晴
# 5    7.6       西南西   11.5         西南西     9.2       --        --            晴
# 6    9.2         北   15.3           北     3.9       --        --       晴後曇一時雨
# 7    6.8       北北西   12.5          北西     9.6       --        --            晴
# 8    6.1        南西   10.4         南南西     9.5       --        --            晴
# 9    8.0         北   12.5           北     5.3       --        --         曇時々晴
# 10   8.6         北   13.4           北     0.3       --        --            曇
# 11   7.5       南南西   11.2         南南西     9.6       --        --            晴
# 12  12.8         北   19.3           北     6.1       --        --  晴時々曇後雨、雷を伴う
# 13  10.0        南西   18.4          南西     9.6       --        --            晴
#
#           天気概要夜
# 0         晴後時々曇
# 1          晴時々曇
# 2          雨時々曇
# 3             晴
# 4             晴
# 5             晴
# 6             晴
# 7         晴後時々曇
# 8             晴
# 9             曇
# 10         晴一時曇
# 11            晴
# 12  晴一時曇、みぞれを伴う
# 13            晴
#
# [14 rows x 21 columns]

# %%
new_scraping_data = scraping_data[['日付', '平均気温','最高気温', '最低気温']]
new_scraping_data = new_scraping_data.rename(columns={'日付': 'date', '平均気温': 'Average', '最高気温': 'Max', '最低気温': 'min'})
new_scraping_data
# Out:
#     date  Average   Max  min
# 0      1     10.0  13.1  5.8
# 1      2      6.6   8.5  4.4
# 2      3      8.2  11.5  4.2
# 3      4     10.3  15.1  7.1
# 4      5      9.1  15.1  4.3
# 5      6     10.9  17.5  4.9
# 6      7      8.6  11.1  6.2
# 7      8      6.2  10.3  3.6
# 8      9      6.7  12.6  1.9
# 9     10      8.0  12.3  3.4
# 10    11      5.7   7.5  4.1
# 11    12      8.3  15.2  1.7
# 12    13      6.4  12.1  2.0
# 13    14      7.4  11.5  1.1

# %%
new_my_data
# Out:
#    date  Average  Max  min
# 0     5     24.0   24   24
# 1     6     22.0   22   22
# 2     8     23.0   23   23
# 3    10     20.0   20   20
# 4    11     18.0   18   18
# 5    13     19.5   20   19
# 9    14     18.3   19   17

# %%
# 平均値の折れ線グラフ
x1 = new_scraping_data['date']
y1 = new_scraping_data['Average']
x2 = new_my_data['date']
y2 = new_my_data['Average']
plt.plot(x1, y1, label="scraping_data")
plt.plot(x2, y2, label="my_data")
plt.legend()

# %%
# scrapingしたデータとmy_dataの数を同じにするためnew_scraping_dataを変える
new_scraping_data_ = new_scraping_data[(new_scraping_data['date'] == 5) | (new_scraping_data['date'] == 6) | (new_scraping_data['date'] == 8) | (new_scraping_data['date'] == 10) | 
                  (new_scraping_data['date'] == 11) | (new_scraping_data['date'] == 13) | (new_scraping_data['date'] == 14)]

# %%
print('new_scraping_data_')
print(f'{new_scraping_data_}\n')
print('new_my_data')
print(new_my_data)
# Out:
# new_scraping_data_
#     date  Average   Max  min
# 4      5      9.1  15.1  4.3
# 5      6     10.9  17.5  4.9
# 7      8      6.2  10.3  3.6
# 9     10      8.0  12.3  3.4
# 10    11      5.7   7.5  4.1
# 12    13      6.4  12.1  2.0
# 13    14      7.4  11.5  1.1
#
# new_my_data
#    date  Average  Max  min
# 0     5     24.0   24   24
# 1     6     22.0   22   22
# 2     8     23.0   23   23
# 3    10     20.0   20   20
# 4    11     18.0   18   18
# 5    13     19.5   20   19
# 9    14     18.3   19   17

# %%
# 散布図
x = new_scraping_data_['Average']
y = new_my_data['Average']
plt.xlabel("scraping_data")
plt.ylabel("my_data")
plt.scatter(x, y)

# %%
# 相関係数
res = x.corr(y)
print(f'相関係数:{res}')
# Out:
# 相関係数:0.83905316872718
